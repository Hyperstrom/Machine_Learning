# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error 
from sklearn.cluster import KMeans 
from sklearn.preprocessing import LabelEncoder,StandardScaler 
from matplotlib import pyplot as plt
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_excel('C:/Users/User/Downloads/CRICKETERS_DATA.xlsx')

# %%
data.head()
# Out:
#    Mat  Inns  Runs    Ave      SR CATEGORY
# 0   58   104  4154  41.95   51.49     TEST
# 1  147   143  5238  39.68   85.25      ODI
# 2   71   122  6147  53.92   58.22     TEST
# 3  211   203  9779  58.20   92.12      ODI
# 4   62    58  2102  48.88  136.22      T20

# %%
le=LabelEncoder()
data.iloc[:,-1]=le.fit_transform(data.iloc[:,-1])

# %%
data.describe()
# Out:
#               Mat        Inns          Runs        Ave          SR   CATEGORY
# count   75.000000   75.000000     75.000000  75.000000   75.000000  75.000000
# mean    93.253333  104.960000   3958.706667  38.392267   90.918400   0.986667
# std     76.785432   79.784412   3585.083627  13.147980   32.969055   0.830066
# min      4.000000    4.000000     61.000000  10.750000   26.700000   0.000000
# 25%     46.500000   55.000000   1483.000000  30.870000   58.665000   0.000000
# 50%     74.000000   86.000000   2779.000000  37.540000   87.180000   1.000000
# 75%    111.500000  140.000000   6029.500000  46.575000  120.995000   2.000000
# max    463.000000  452.000000  18426.000000  99.940000  161.530000   2.000000

# %%
sc=StandardScaler()
data.iloc[:,:-1]=sc.fit_transform(data.iloc[:,:-1])

# %%
X=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
X
# Out:
#          Mat      Inns      Runs       Ave        SR
# 0  -0.462207 -0.012113  0.054841  0.272414 -1.203975
# 1   0.704673  0.479996  0.359241  0.098601 -0.173089
# 2  -0.291764  0.215014  0.614499  1.188951 -0.998469
# 3   1.543777  1.237086  1.634408  1.516668  0.036692
# 4  -0.409763 -0.592550 -0.521385  0.803040  1.383317
# ..       ...       ...       ...       ...       ...
# 70 -0.213098 -0.428513 -0.599170 -0.088228  1.019637
# 71 -0.409763  0.000505  0.238772  0.855873 -1.344134
# 72 -0.894870 -0.781822 -0.696331  0.120806 -1.092519
# 73  1.176669  0.909014  0.783267  0.504419 -0.114155
# 74 -0.121320 -0.352804 -0.525878 -0.444277  1.408662
#
# [75 rows x 5 columns]

# %%
y
# Out:
# 0     2
# 1     0
# 2     2
# 3     0
# 4     1
#      ..
# 70    1
# 71    2
# 72    2
# 73    0
# 74    1
# Name: CATEGORY, Length: 75, dtype: int32

# %%
data
# Out:
#          Mat      Inns      Runs       Ave        SR  CATEGORY
# 0  -0.462207 -0.012113  0.054841  0.272414 -1.203975         2
# 1   0.704673  0.479996  0.359241  0.098601 -0.173089         0
# 2  -0.291764  0.215014  0.614499  1.188951 -0.998469         2
# 3   1.543777  1.237086  1.634408  1.516668  0.036692         0
# 4  -0.409763 -0.592550 -0.521385  0.803040  1.383317         1
# ..       ...       ...       ...       ...       ...       ...
# 70 -0.213098 -0.428513 -0.599170 -0.088228  1.019637         1
# 71 -0.409763  0.000505  0.238772  0.855873 -1.344134         2
# 72 -0.894870 -0.781822 -0.696331  0.120806 -1.092519         2
# 73  1.176669  0.909014  0.783267  0.504419 -0.114155         0
# 74 -0.121320 -0.352804 -0.525878 -0.444277  1.408662         1
#
# [75 rows x 6 columns]

# %%
model=KMeans(n_clusters=3)
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
model
# Out:
# KMeans(n_clusters=3)

# %%
plt.scatter(X.iloc[:,2],X.iloc[:,3],c=model.labels_)
plt.show()
