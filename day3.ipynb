# %%
import pandas as pd 
import numpy as np

# %%
df_1 = pd.read_csv("C:\\Users\\anike\\Downloads\\practice excel\\Q2_bollywood.csv")

# %%
df_1
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
len(dir(df_1))
# Out:
# 439

# %%
type(df_1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# pandas operation

# %%
#Descriptive stats
#Infertial = hypothisis testing
#Predictive

# %% [markdown]
# Descriptive Stats

# %%
df_1.dtypes
# Out:
# SlNo                     int64
# Release Date            object
# MovieName               object
# ReleaseTime             object
# Genre                   object
# Budget                   int64
# BoxOfficeCollection    float64
# YoutubeViews             int64
# YoutubeLikes             int64
# YoutubeDislikes          int64
# dtype: object

# %%
df_1.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
df_1
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df_1.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df_1.tail()
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649

# %%
df_1.sample(5) #random 5 samples
# Out:
#      SlNo Release Date           MovieName ReleaseTime     Genre  Budget  \
# 95     96    28-Jun-13         Ghanchakkar           N    Comedy      30
# 98     99    18-Jul-14            Pizza 3D           N  Thriller      10
# 144   145    27-Feb-15  Dum Laga Ke Haisha           N    Comedy      15
# 31     32    15-Feb-13            Murder 3          FS  Thriller      12
# 137   138    16-Jan-15               Alone           N  Thriller      18
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 95                 38.00       2248046          5108              614
# 98                  4.35        838943          1116              153
# 144                30.00       3250917          8185              615
# 31                 25.00       2249055          1879              747
# 137                25.00       8788913         18907             2940

# %%
df_1.sample(5,random_state=101)
# Out:
#      SlNo Release Date     MovieName ReleaseTime      Genre  Budget  \
# 16     17    25-Jan-13        Race 2          LW  Thriller       60
# 55     56     9-May-14     Manjunath          HS     Drama        3
# 124   125    29-Nov-13  Bullett Raja           N     Comedy      50
# 89     90    19-Dec-14            PK          HS     Drama       85
# 32     33    23-May-14     Heropanti          HS    Romance      21
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 16                162.00       7641333         12617             2138
# 55                  1.75        370106           991               35
# 124                40.00       4015674          8084             2129
# 89                735.00      13270623         43767             5693
# 32                 65.00       4005695          8189             1814

# %%
df_1["YoutubeViews"].max() # .min(),# .std(),# .mean()
# Out:
# 23171067

# %%
df_1_Comedy = df_1[df_1["Genre"]== "Comedy"] #arrange the data through comedy

# %%
df_1_Comedy
# Out:
#      SlNo Release Date                    MovieName ReleaseTime   Genre  \
# 2       3    18-Jul-14           Amit Sahni Ki List           N  Comedy
# 4       5     4-Jul-14                 Bobby Jasoos           N  Comedy
# 6       7    19-Sep-14                Daawat-E-Ishq           N  Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N  Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW  Comedy
# 14     15     8-Aug-14                Entertainment           N  Comedy
# 17     18     6-Jun-14                   Filmistaan          HS  Comedy
# 18     19    12-Sep-14                Finding Fanny           N  Comedy
# 19     20    13-Jun-14                        Fugly          HS  Comedy
# 39     40    20-Jun-14                   Humshakals          HS  Comedy
# 46     47    15-Mar-13           Mere Dad Ki Maruti           N  Comedy
# 47     48    15-Mar-13                    Jolly LLB           N  Comedy
# ...

# %%
len(df_1_Comedy)
# Out:
# 36

# %%
df_1_Comedy_bud = df_1_Comedy[df_1_Comedy["Budget"]>40] #comedy movies above 40 budget

# %%
df_1_Comedy_bud
# Out:
#      SlNo Release Date               MovieName ReleaseTime   Genre  Budget  \
# 14     15     8-Aug-14           Entertainment           N  Comedy      60
# 39     40    20-Jun-14              Humshakals          HS  Comedy      75
# 75     76    28-Feb-14  Shaadi Ke Side Effects           N  Comedy      50
# 96     97     2-Oct-13                Besharam          LW  Comedy      85
# 115   116     9-Aug-13         Chennai Express          FS  Comedy      75
# 124   125    29-Nov-13            Bullett Raja           N  Comedy      50
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 14                 163.0       6336058         20472             2843
# 39                  63.7       6280868             1                1
# 75                  37.8       4590539          9021             1465
# 96                  35.0       5319606         10253             8165
# 115                395.0       1882346          7954             1593
# ...

# %%
#LOC ------- By Name 
#ILOC ------ By Position

# %%
df_1.iloc[:,0:3] # coloumn position
# Out:
#      SlNo Release Date                    MovieName
# 0       1    18-Apr-14                     2 States
# 1       2     4-Jan-13                 Table No. 21
# 2       3    18-Jul-14           Amit Sahni Ki List
# 3       4     4-Jan-13             Rajdhani Express
# 4       5     4-Jul-14                 Bobby Jasoos
# ..    ...          ...                          ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha
# 145   146    13-Mar-15                         NH10
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend
# 147   148    20-Mar-15                     Hunterrr
# 148   149    23-May-14                Kochadaiiyaan
#
# [149 rows x 3 columns]

# %%
df_1.iloc[23:33,:]
# Out:
#     SlNo Release Date                  MovieName ReleaseTime     Genre  \
# 23    24     2-Oct-14                     Haider          FS    Drama
# 24    25    21-Nov-14               Happy Ending           N   Romance
# 25    26     8-Feb-13                 Special 26           N    Drama
# 26    27    24-Oct-14             Happy New Year          LW    Drama
# 27    28     8-Feb-13  ABCD _ Any Body Can Dance           N    Drama
# 28    29    18-Jul-14               Hate Story 2           N  Thriller
# 29    30     9-May-14               Hawaa Hawaai          HS    Drama
# 30    31     7-Feb-14                  Heartless           N  Thriller
# 31    32    15-Feb-13                   Murder 3          FS  Thriller
# 32    33    23-May-14                  Heropanti          HS   Romance
#
#     Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 23      24                69.00       7048104         23590             2443
# ...

# %%
df_1.loc[:,"MovieName":"Budget"] #Loc by the name
# Out:
#                        MovieName ReleaseTime      Genre  Budget
# 0                       2 States          LW    Romance      36
# 1                   Table No. 21           N  Thriller       10
# 2             Amit Sahni Ki List           N     Comedy      10
# 3               Rajdhani Express           N     Drama        7
# 4                   Bobby Jasoos           N     Comedy      18
# ..                           ...         ...        ...     ...
# 144           Dum Laga Ke Haisha           N     Comedy      15
# 145                         NH10           N   Thriller      13
# 146  Dilliwali Zaalim Girlfriend           N     Comedy      32
# 147                     Hunterrr           N     Comedy       5
# 148                Kochadaiiyaan          HS     Action     150
#
# [149 rows x 4 columns]

# %% [markdown]
# Visualization
#
# Matplotlip
#
# Seaborn
#
# plotly

# %%
from matplotlib import pyplot as plt

# %%
x_input = list(range(0,10,2))
y_output = x_input

# %%
y_output
# Out:
# [0, 2, 4, 6, 8]

# %%
x_input
# Out:
# [0, 2, 4, 6, 8]

# %%
z_out = [2,3,6,12,8]

# %%
plt.plot(x_input,z_out,c="orange")
plt.plot(y_output,z_out,c="black")
plt.xlabel("X.......")
plt.ylabel("Y.......")
# Out:
# Text(0, 0.5, 'Y.......')

# %%
import seaborn as sns

# %%
sns.countplot(x = "Genre", data = df_1)
plt.show()

# %% [markdown]
# Skewness

# %%
df_3 = df_1.iloc[:,5:]
df_3
# Out:
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0        36               104.00       8576361         26622             2527
# 1        10                12.00       1087320          1129              137
# 2        10                 4.00        572336           586               54
# 3         7                 0.35         42626            86               19
# 4        18                10.80       3113427          4512             1224
# ..      ...                  ...           ...           ...              ...
# 144      15                30.00       3250917          8185              615
# 145      13                32.10       5592977         15464             1513
# 146      32                12.00       2316047          4289              807
# 147       5                11.89       4674795          3706              762
# 148     150               120.00       4740727         13466             2649
#
# [149 rows x 5 columns]

# %%
df_3.skew()
# Out:
# Budget                 2.059560
# BoxOfficeCollection    3.980880
# YoutubeViews           2.667002
# YoutubeLikes           4.391138
# YoutubeDislikes        3.534963
# dtype: float64

# %%
sns.displot(df_3,x="Budget")
plt.show()

# %%
sns.displot(df_3,x="Budget",kind = "kde")
plt.show()
